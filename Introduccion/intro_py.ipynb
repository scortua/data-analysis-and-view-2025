# %% [markdown]
# # Introduccion a Python

# %% [markdown]
# ## Por qué **Python** y **Tableau**
#
# La herramienta no es lo más importante, pero si es verdad que python es uno de los lenguajes de alto nivel con una comunidad muy viva que permite aprender y diseñar, como cientificos o ingeniros.
#
# Tableau es un tipo de powerby pero de pago para ver visualizacion de datos, al igual que excel o google sheet.
#
# Es importante usar herramientas dependiendo de la necesidad, no necesariamente uno debe apegarse a una sola herramienta.

# %% [markdown]
# ## A,B,C,D Estadistica Descriptiva
#
# [Para leer](https://web.archive.org/web/20230608212927/https://reporterodedatos.com/media-mediana-moda-y-otras-medidas-de-resumen/)
#
# * Media, Mediana y Moda $\rightarrow$ medidas de tendencia central
# * Varianza y Desviacion Estandar $\rightarrow$ medidas de dispercion
# * Percentiles $\rightarrow$ medida de posicion

# %% [markdown]
# Para entender estas medidas rapidamente se hace una analogia:
#
# Tenemos 11 estudiantes y sus edades:
#
# 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 🧑‍💻 -> 20 22 22 23 23 24 28 28 28 32 45
#
# **La media** $20+22+22+23+23+24+28+28+28+32+45 = 295 / 11 = 26.82$ o sea es el total de la suma dividido el total del conjunto
#
# **La mediana** $20-22-23-24-28-32-45 \rightarrow 24$ el valor intermedio de los datos
#
# **La moda** es el 28 porque es el valor que se repite mas en los valores
#
# **Desviación Estandar** permite ver que tan alejados estan los datos de la media, mientras _mayor sea el valor_ los datos estan más dispersos y entre _menor sea el valor_ mas iguales seran.
#
# **Percentiles** agrupa los datos en diversos grupos en:
#     * Percentiles que dividen los datos en 100
#     * Quartiles que dividen los datos en 4 grupos
#     * Deciles dividen datos en 10 grupos

# %% [markdown]
# # Aleatoriedad
#
# La aleatoriedad es la ausencia de un patrón determinista en el comportamiento de un fenómeno; los resultados individuales no pueden predecirse con certeza aunque sí puedan describirse con probabilidades. En términos prácticos, la aleatoriedad permite modelar la incertidumbre y variabilidad en datos y procesos.
#
# Conceptos clave:
# - Variable aleatoria: magnitud cuyo valor depende del resultado de un experimento aleatorio y se describe por una distribución de probabilidad (p. ej., uniforme, normal, binomial).
# - Distribución y parámetros: la probabilidad de distintos resultados se resume en una función de densidad o masa y parámetros (media, varianza, etc.).
# - Entropía: medida de incertidumbre o “sorpresa” en una distribución; mayor entropía indica mayor aleatoriedad.
#
# Tipos de aleatoriedad:
# - Aleatoriedad verdadera: generada por fenómenos físicos impredecibles (ruido térmico, procesos cuánticos).
# - Pseudoaleatoriedad: secuencias generadas por algoritmos deterministas (generadores pseudoaleatorios). Son reproducibles mediante una semilla y aptos para simulaciones pero no para usos criptográficos sensibles sin cuidado.
#
# Aplicaciones prácticas:
# - Muestreo y experimentos: garantizar representatividad y evitar sesgos.
# - Simulación Monte Carlo: aproximación numérica de integrales y probabilidades usando muestras aleatorias.
# - Criptografía: requiere fuentes de aleatoriedad de alta calidad para claves y noces.
# - Pruebas estadísticas: detectar si una secuencia o muestra es compatible con un modelo aleatorio (tests de aleatoriedad, autocorrelación, pruebas de uniformidad).
#
# Consideraciones:
# - Reproducibilidad: en análisis y simulaciones se usa una semilla para poder reproducir resultados cuando se emplean generadores pseudoaleatorios.
# - Calidad del generador: evaluar periodos, autocorrelación y propiedades estadísticas según la aplicación.
# - Distinción entre variabilidad aleatoria y efectos sistemáticos: importante para interpretar resultados y diseñar experimentos.
#
# En resumen, la aleatoriedad es una herramienta fundamental para modelar incertidumbre; entender su origen y propiedades (verdadera vs pseudoaleatoria, medidas de dispersión y tests) es clave para aplicar métodos estadísticos y computacionales de forma correcta.

# %% [markdown]
# # Probabilidad
#
# La probabilidad es una medida numérica que cuantifica la incertidumbre sobre la ocurrencia de un evento. Permite asignar un valor entre 0 y 1 a cada evento, donde 0 indica imposibilidad y 1 certeza.
#
# ## Interpretaciones
# - Clásica: P(A) = número de casos favorables / número de casos iguales posibles (útil en espacios finitos y simétricos: dados, cartas).
# - Frequentista: P(A) es el límite de la frecuencia relativa de A al repetir el experimento muchas veces.
# - Bayesiana: P(A) representa el grado de creencia sobre A, actualizado con datos mediante el teorema de Bayes.
#
# ## Fundamentos axiomáticos (Kolmogórov)
# Sea Ω el espacio muestral y A, B eventos:
# 1. 0 ≤ P(A) ≤ 1
# 2. P(Ω) = 1
# 3. Para eventos mutuamente excluyentes Ai, P(∪ Ai) = Σ P(Ai)
#
# De estos se derivan propiedades útiles:
# - Complemento: P(A^c) = 1 − P(A)
# - Unión: P(A ∪ B) = P(A) + P(B) − P(A ∩ B)
# - Si A ⊆ B entonces P(A) ≤ P(B)
#
# ## Probabilidad condicional e independencia
# - Probabilidad condicional: P(A | B) = P(A ∩ B) / P(B), siempre que P(B) > 0.
# - Independencia: A y B son independientes si P(A ∩ B) = P(A) P(B) (equivalente a P(A | B) = P(A)).
#
# ## Leyes importantes
# - Ley de los grandes números: la frecuencia relativa converge a la probabilidad verdadera al aumentar el número de repeticiones.
# - Teorema central del límite: la suma (o media) de muchas variables aleatorias independientes y con varianza finita tiende a una distribución aproximadamente normal.
#
# ## Ejemplos rápidos
# - Moneda justa: P(cara) = 0.5.
# - Dado justo: P(obtener 6) = 1/6.
# - Condicional: si extraes dos bolas de una urna sin reemplazo, P(segunda roja | primera roja) cambia respecto a con reemplazo.
#
# ## Aplicaciones prácticas
# - Estadística inferencial, diseño de experimentos, pruebas de hipótesis.
# - Modelado en finanzas, aseguradoras, control de calidad, aprendizaje automático y simulaciones Monte Carlo.
# - Toma de decisiones bajo incertidumbre y optimización estocástica.
#
# Consejo: explicita siempre el espacio muestral y las suposiciones (independencia, tamaño de muestra, modelo) antes de aplicar fórmulas o interpretar resultados.

# %% [markdown]
# ![Tipos de variables](Images/TiposDeVariables.png)

# %% [markdown]
# # Tipos de variables (4)
#
# - **Categórica nominal**
#     Descripción: categorías sin orden intrínseco.
#     Ejemplo: Color del coche = {rojo, azul, verde}.
#
# - **Categórica ordinal**
#     Descripción: categorías con orden pero sin distancia numérica fija.
#     Ejemplo: Nivel educativo = {Primaria < Secundaria < Universidad}.
#
# - **Numérica discreta**
#     Descripción: valores numéricos contables enteros.
#     Ejemplo: Número de hijos = {0, 1, 2, 3, ...}.
#
# - **Numérica continua**
#     Descripción: valores numéricos en un intervalo, pueden tomar decimales.
#     Ejemplo: Altura (cm) = 172.4, 160.0, 185.2.

# %% [markdown]
# # Distribuciones
#
# [para leer](https://www.jmp.com/es/statistics-knowledge-portal/exploratory-data-analysis/histogram)
#
# ## Histograma
# Por columnas de varios datos en cantidades bien distribuidas permite entender los datos a partir de gráficas de una variable (frecuencias). El histograma agrupa valores en "bins" (intervalos) y muestra la altura proporcional a la cantidad de observaciones en cada bin. Ajustando el tamaño de los bins se puede ver más detalle o suavizar la forma; es útil para detectar asimetrías, picos, vacíos y valores atípicos.
#
# ### Distribuciones Normales
# Distribución simétrica en forma de campana; caracterizada por la media (μ) y la desviación estándar (σ). La media, mediana y moda coinciden en el centro. Muchos fenómenos naturales y errores aleatorios se aproximan a esta forma. En un histograma se observa un único pico central y colas que decrecen suavemente hacia ambos lados.
#
# ### Distribuciones sesgadas Derecha o Izquierda
# Sesgo derecho (asimetría positiva): cola más larga hacia valores grandes; la media > mediana > moda. Indica datos con algunos valores atípicos altos (ej.: ingresos).
# Sesgo izquierdo (asimetría negativa): cola más larga hacia valores pequeños; la media < mediana < moda. Indica presencia de valores atípicos bajos. El histograma muestra un lado más extendido que el otro.
#
# ### Distribuciones Uniformes
# Todos los valores en un rango tienen aproximadamente la misma probabilidad; el histograma se ve plano (sin picos claros). Se usa como modelo cuando no hay tendencia ni agrupamiento en los datos dentro de un intervalo.
#
# ### Distribuciones Bimodales
# Presentan dos picos pronunciados, lo que sugiere la mezcla de dos subpoblaciones o procesos diferentes dentro del mismo conjunto de datos (ej.: alturas agrupadas por dos grupos). En el análisis conviene investigar causas (mezcla de grupos, errores de medición, variables categóricas ocultas).
#
# ### Distribuciones Multimodales
# Tienen más de dos picos; indican heterogeneidad compleja (varias subpoblaciones o procesos). Requieren explorar segmentación, transformaciones o modelos que capten la mezcla (p. ej., modelos de mezcla gaussiana) para entender las fuentes de variabilidad.

# %% [markdown]
# # Tratar los datos
# ## Inspeccion
# * Inspecciona los datos
# * verifica columnas y tipos de datos
# * cuales son los rangos
# * determinar valores NaN y no perder de vista el objetivo
# ## Curacion
# * corregir tipos de variables
# * tratar datos NaN
# * transformar datos str a numeros
# * calcular nuevas columnas
# * filtrar datos necesarios de innecesarios
# * Filtracion y agrupacion categorica
# ## Exploracion Visual
# * analisasa correlaciones
# * entender patrones
# * buscar proporciones
# * entender graficos
# # Ingenieria de datos - Machine Learning
# * Entendiemiento de uso de los datos

# %% [markdown]
# # Visualizacion de datos
# * Visualizacion de una variable
# * Visualizaciones de mas de una variable
# * Visualizaciones geograficas
# * Visualizaciones de redes
# * visualizaciones jerargicas
# * Otras visualizaciones
#
# Se pueden ver mas sobre visualizaciones en [Catalogo de visualizaciones](https://datavizcatalogue.com/ES/) y en [Funcionalidad de visualizaciones](https://datavizcatalogue.com/ES/buscar.html)

# %% [markdown]
# # El cuarteto de Anscombe
#
# El cuarteto de Anscombe (Francis Anscombe, 1973) es un conjunto de cuatro pares de datos diseñados para ilustrar la importancia de visualizar los datos además de calcular estadísticos resumen. Los cuatro conjuntos tienen prácticamente los mismos valores de media, varianza, correlación y recta de regresión lineal, pero presentan patrones gráficos muy distintos.
#
# - Objetivo: mostrar que medidas resumen (media, varianza, correlación, coeficiente de regresión) pueden ocultar estructuras muy diferentes en los datos. La visualización revela esas diferencias y evitando conclusiones engañosas.
# - Propiedades compartidas: para las cuatro series los valores de media de X e Y, la varianza, la correlación de Pearson y la recta de regresión lineal son (casi) idénticos.
# - Diferencias gráficas típicas:
#     - Conjunto I: relación claramente lineal, dispersión homogénea alrededor de la recta.
#     - Conjunto II: relación claramente no lineal (curva), la regresión lineal explica mal la forma real.
#     - Conjunto III: relación lineal aparente pero influenciada por un outlier en Y que distorsiona los parámetros.
#     - Conjunto IV: la mayoría de puntos alineados verticalmente (poca variación en X) y un outlier en X que genera la pendiente aparente.
#
# Lecciones prácticas
# - Siempre graficar los datos (dispersogramas, boxplots, histogramas) antes de interpretar estadísticos o ajustar modelos.
# - Comprobar supuestos del modelo: linearidad, homocedasticidad, ausencia de outliers influyentes.
# - Usar métodos robustos cuando haya outliers o distribuciones asimétricas (medianas, estimadores robustos).
# - Complementar medidas globales con análisis exploratorio visual y análisis de residuos para evitar conclusiones erróneas.
#
# El cuarteto de Anscombe es un clásico en enseñanza de estadística y ciencia de datos para recordar que la visualización es esencial en el análisis exploratorio.
#
# ![cuarteto anscombe](Images/cuartetoanscombe.png)

# %% [markdown]
# # Importancia UI/UX para Visualizaciones
# Leer sobre [Daltonismo](https://es.wikipedia.org/wiki/Daltonismo) y [Tipos de colores](https://www.datawrapper.de/blog/colors). [Ayudante de mix color](https://pigment-shapefactory-co.translate.goog/?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es-419&_x_tr_pto=sc&_x_tr_hist=true).
# 1. El color
#     * Resalta
#     * Introduce variables
#     * Su uso no limita estetica
#     * Deben de ser funcionales
# 2. Texto
#     * Visualizacion eficiente con el texto necesario no largo explicativo
#     * menos texto mejor
#     * explicaciones puntuales
#     * las leyendas deben ser justas para entender
# 3. Complejidad
#     * No importa que sea compleja o facil un grafico pero si importa que sea entendible
#     * Multiples graficos sin colores definidos e inconsistencias con texto que impiden entender facil la visualizacion
#     * Mas complejidad = Mas dificil la visualizacion
#     * Visualizacion que permite categorizar facilmente al ver
#     * Ponerse en los zapatos de quien la ve por primera vez
#     * Nada esta escrito en piedra y por ello es bueno seguir directrices de la mente humana

# %% [markdown]
# # Confidencialidad
# - Principios generales
#     - Minimizar: recoger y conservar solo los datos estrictamente necesarios para el objetivo declarado.
#     - Propósito y consentimiento: definir claramente el uso y, cuando proceda, obtener consentimiento informado.
#     - Legitimidad y cumplimiento: cumplir normativas aplicables (p. ej. GDPR, leyes locales) y políticas internas.
#
# - Protección de la identidad
#     - Anonimizar o pseudonimizar datos personales antes de análisis o compartición.
#     - Evitar reidentificación: revisar combinaciones de variables que puedan identificar individuos.
#     - Considerar técnicas avanzadas (differential privacy, agregación) para resultados públicos.
#
# - Seguridad y acceso
#     - Controlar accesos por roles (principio de menor privilegio).
#     - Cifrar datos en tránsito y en reposo.
#     - Mantener registros de acceso y auditorías para trazabilidad.
#
# - Calidad y trazabilidad
#     - Documentar orígenes, transformaciones, versiones de datasets y decisiones de limpieza.
#     - Mantener pipelines reproducibles (scripts, semillas aleatorias, entornos).
#     - Validar y revisar resultados para detectar errores o sesgos.
#
# - Retención y eliminación
#     - Definir políticas de retención según el propósito y la legislación.
#     - Eliminar o anonimizar datos al terminar el periodo necesario.
#
# - Compartición y publicación
#     - Compartir solo lo necesario y bajo acuerdos (NDA, licencias).
#     - Publicar ejemplos sintéticos o agregados cuando la privacidad sea un riesgo.
#     - Revisar outputs (tablas, visualizaciones) para evitar filtración accidental de datos sensibles.
#
# - Evaluación de riesgos y ética
#     - Realizar evaluaciones de impacto de privacidad (PIA) cuando corresponda.
#     - Considerar consecuencias éticas y sociales de modelos y decisiones automatizadas.
#     - Incorporar revisión por pares y supervisión continua.
#
# Buenas prácticas rápidas: usar entornos aislados para datos sensibles, aplicar control de versiones, automatizar pruebas de privacidad y documentar decisiones para garantizar responsabilidad y reproducibilidad.
