# %% [markdown]
# # Nube de Palabras (WordCloud)
# Es un gráfico sin ejes que muestra diversas palabras pertenecientes a un texto o a un grupo de textos. El tamaño de cada palabra codifica que tan "importante" es la palabra dentro del texto o de los textos. Esta "importancia" puede significar diferentes métricas: Frecuencia Absoluta, Frecuencia Relativa, TF-IDF, etc. Usualmente es el primer gráfico que se realiza como exploración a una columna de tipo texto.
#
# ![image-15.png](attachment:image-15.png)
#
# ### Consejos
# - Su propósito no es representar presición. Es utilizado más a modo de presentación o inspección rápida.
# - Si quiero presentar con presición cuales son las palabras más "importantes" de mi texto es preferible un gráfico de barras (Eje X: cada palabra, Eje Y: medida de importancia de cada palabra).
# - Puedo darle forma a mi WordCloud para hacerlo más llamativo
#
# ![image-17.png](attachment:image-17.png)
#
# ## Referencias
# - https://datavizcatalogue.com/ES/metodos/nube_de_palabras.html

# %%
# %pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from wordcloud) (2.3.3)
# Requirement already satisfied: pillow in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/marcas_mensajes_twitter.csv')
df[['created_at', 'cx_brand', 'message']].tail(10)
# Out:
#                            created_at      cx_brand  \
# 53504  Fri Apr 12 12:31:15 +0000 2019        Target
# 53505  Fri Apr 12 10:43:56 +0000 2019        Target
# 53506  Sun Apr 21 13:51:57 +0000 2019  TiffanyAndCo
# 53507  Tue Apr 16 14:15:27 +0000 2019  TiffanyAndCo
# 53508  Tue Apr 16 14:53:35 +0000 2019        BNBuzz
# 53509  Mon Apr 15 19:17:33 +0000 2019        BNBuzz
# 53510  Mon Apr 15 00:43:22 +0000 2019        BNBuzz
# 53511  Sat Apr 13 22:50:35 +0000 2019        BNBuzz
# 53512  Sat Apr 13 20:46:24 +0000 2019        BNBuzz
# 53513  Sat Apr 13 19:19:54 +0000 2019        BNBuzz
#
#                                                  message
# 53504  Thank you so much to the Hyattsville @Target s...
# 53505  Just found out the album won’t be sold at my @...
# 53506  #Sunday is a great day to plan our next trip t...
# 53507  @TiffanyAndCo Just wondered if there was any d...
# 53508  Why are the employees at @BNBuzz 82/Broadway a...
# 53509  @BNBuzz Hello do you know if your site is expe...
# 53510  Hey @BNBuzz - was disappointed today to discov...
# 53511  Just called @BNBuzz to reserve my copy of #mil...
# 53512  I'll never buy an ebook from @BNBuzz again. I ...
# 53513  @BNBuzz terrible UX. For the life of me I cann...

# %%
df = df.drop_duplicates(subset=['message'])

# %%
texto = ' '.join(df['tokenized'])

# %%
# Wordcloud con Matplotlib y una libreria adicional 
# https://github.com/amueller/word_cloud
wc = WordCloud(
    width=1000,
    height=700,
    margin=0,
    background_color='black' # white
).generate(texto)
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(999.5), np.float64(699.5), np.float64(-0.5))

# %%
# %pip install pillow
# Out:
# Requirement already satisfied: pillow in s:\documents\sena y cursos\ibm\visualizacion y analisis datos 2025\myenv\lib\site-packages (11.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import numpy as np

# %%
tw_color = np.array(Image.open('images/twitter.jpeg'))
tw_mask = tw_color.copy()
tw_mask[tw_mask.sum(axis=2) == 0] = 255

# %%
wc = WordCloud(
    margin=0,
    mask=tw_mask
).generate(texto)

image_colors = ImageColorGenerator(tw_color)
wc.recolor(color_func=image_colors)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
wc.to_file("./wc_tw.png")

# %% [markdown]
# ## Wordclouds sin Python
#
# También pueden generar Wordclouds con herramientas online con una interfaz grafica:
# https://www.nubedepalabras.es/
#
# Desventaja: Estas herramientas Online no soportan una cantidad grande de texto
